# %%
import pandas as pd
df = pd.read_csv("mckinsey.csv")

# %%
df.nunique()
# Out:
# country        142
# year            13
# population    1705
# continent        5
# life_exp      1627
# gdp_cap       1705
# dtype: int64

# %%
df.loc[df.shape[0]] = ["India",2020,50302023,"Asia",65.834,659.854]
df.loc[df.shape[0]] = ["India",2020,50302023,"Asia",65.834,659.854]
df.loc[df.shape[0]] = ["India",2020,50302023,"Asia",65.834,659.854]
df.loc[df.shape[0]] = ["India",2020,50302023,"Asia",65.834,659.854]

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2020    50302023      Asia    65.834  659.854000
# 1705     India  2020    50302023      Asia    65.834  659.854000
# 1706     India  2020    50302023      Asia    65.834  659.854000
# 1707     India  2020    50302023      Asia    65.834  659.854000

# %%
df.loc[df.duplicated()]
# Out:
#      country  year  population continent  life_exp  gdp_cap
# 1705   India  2020    50302023      Asia    65.834  659.854
# 1706   India  2020    50302023      Asia    65.834  659.854
# 1707   India  2020    50302023      Asia    65.834  659.854

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020    50302023      Asia    65.834  659.854000
#
# [1705 rows x 6 columns]

# %%
df.drop_duplicates(subset="country",keep="last")
# Out:
#                  country  year  population continent  life_exp       gdp_cap
# 11           Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23               Albania  2007     3600523    Europe    76.423   5937.029526
# 35               Algeria  2007    33333216    Africa    72.301   6223.367465
# 47                Angola  2007    12420476    Africa    42.731   4797.231267
# 59             Argentina  2007    40301927  Americas    75.320  12779.379640
# ...                  ...   ...         ...       ...       ...           ...
# 1667  West Bank and Gaza  2007     4018332      Asia    73.422   3025.349798
# 1679         Yemen, Rep.  2007    22211743      Asia    62.698   2280.769906
# 1691              Zambia  2007    11746035    Africa    42.384   1271.211593
# 1703            Zimbabwe  2007    12311143    Africa    43.487    469.709298
# 1704               India  2020    50302023      Asia    65.834    659.854000
#
# [142 rows x 6 columns]

# %%
df.loc[(df["continent"]=="Africa") & (df["life_exp"]<50)]
# Out:
#        country  year  population continent  life_exp      gdp_cap
# 24     Algeria  1952     9279525    Africa    43.077  2449.008185
# 25     Algeria  1957    10270856    Africa    45.685  3013.976023
# 26     Algeria  1962    11000948    Africa    48.303  2550.816880
# 36      Angola  1952     4232095    Africa    30.015  3520.610273
# 37      Angola  1957     4561361    Africa    31.999  3827.940465
# ...        ...   ...         ...       ...       ...          ...
# 1691    Zambia  2007    11746035    Africa    42.384  1271.211593
# 1692  Zimbabwe  1952     3080907    Africa    48.451   406.884115
# 1701  Zimbabwe  1997    11404948    Africa    46.809   792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989   672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487   469.709298
#
# [373 rows x 6 columns]

# %%
df.loc[(df["continent"]=="Africa") & (df["life_exp"]<40),["country","year"]]
# Out:
#         country  year
# 36       Angola  1952
# 37       Angola  1957
# 38       Angola  1962
# 39       Angola  1967
# 40       Angola  1972
# ...         ...   ...
# 1463  Swaziland  2007
# 1536       Togo  1952
# 1584     Uganda  1952
# 1690     Zambia  2002
# 1702   Zimbabwe  2002
#
# [98 rows x 2 columns]

# %%
df["life_exp"].mean()
# Out:
# 59.478169313782985

# %%
df.sort_values(by=["year"],ascending=False).head(10)
# Out:
#              country  year  population continent  life_exp       gdp_cap
# 1704           India  2020    50302023      Asia    65.834    659.854000
# 1607  United Kingdom  2007    60776238    Europe    79.425  33203.261280
# 887          Lesotho  2007     2012649    Africa    42.592   1569.331442
# 683          Hungary  2007     9956108    Europe    73.338  18008.944440
# 1043      Mozambique  2007    19951656    Africa    42.082    823.685621
# 167         Botswana  2007     1639131    Africa    50.728  12569.851770
# 1403         Somalia  2007     9118773    Africa    48.159    926.141068
# 1631         Uruguay  2007     3447496  Americas    76.384  10611.462990
# 899          Liberia  2007     3193942    Africa    45.678    414.507341
# 179           Brazil  2007   190010647  Americas    72.390   9065.800825

# %%
df.sort_values(by=["year","life_exp"]).head(10)
# Out:
#             country  year  population continent  life_exp      gdp_cap
# 0       Afghanistan  1952     8425333      Asia    28.801   779.445314
# 552          Gambia  1952      284320    Africa    30.000   485.230659
# 36           Angola  1952     4232095    Africa    30.015  3520.610273
# 1344   Sierra Leone  1952     2143249    Africa    30.331   879.787736
# 1032     Mozambique  1952     6446316    Africa    31.286   468.526038
# 192    Burkina Faso  1952     4469979    Africa    31.975   543.255241
# 624   Guinea-Bissau  1952      580653    Africa    32.500   299.850319
# 1668    Yemen, Rep.  1952     4963829      Asia    32.548   781.717576
# 1392        Somalia  1952     2526994    Africa    32.978  1135.749842
# 612          Guinea  1952     2664249    Africa    33.609   510.196492

# %%
df.sort_values(by=["year","life_exp"],ascending=[True,False]).head(10)
# Out:
#              country  year  population continent  life_exp       gdp_cap
# 1140          Norway  1952     3327728    Europe     72.67  10095.421720
# 684          Iceland  1952      147962    Europe     72.49   7267.688428
# 1080     Netherlands  1952    10381988    Europe     72.13   8941.571858
# 1464          Sweden  1952     7124673    Europe     71.86   8527.844662
# 408          Denmark  1952     4334000    Europe     70.78   9692.385245
# 1476     Switzerland  1952     4815000    Europe     69.62  14734.232750
# 1092     New Zealand  1952     1994794   Oceania     69.39  10556.575660
# 1596  United Kingdom  1952    50430000    Europe     69.18   9979.508487
# 60         Australia  1952     8691212   Oceania     69.12  10039.595640
# 240           Canada  1952    14785584  Americas     68.75  11367.161120

# %%
df.sort_values(by=["year","life_exp"],ascending=[False,True]).head(10)
# Out:
#                        country  year  population continent  life_exp  \
# 1704                     India  2020    50302023      Asia    65.834
# 1463                 Swaziland  2007     1133066    Africa    39.613
# 1043                Mozambique  2007    19951656    Africa    42.082
# 1691                    Zambia  2007    11746035    Africa    42.384
# 1355              Sierra Leone  2007     6144562    Africa    42.568
# 887                    Lesotho  2007     2012649    Africa    42.592
# 47                      Angola  2007    12420476    Africa    42.731
# 1703                  Zimbabwe  2007    12311143    Africa    43.487
# 11                 Afghanistan  2007    31889923      Asia    43.828
# 263   Central African Republic  2007     4369038    Africa    44.741
#
#           gdp_cap
# 1704   659.854000
# 1463  4513.480643
# 1043   823.685621
# 1691  1271.211593
# 1355   862.540756
# 887   1569.331442
# 47    4797.231267
# 1703   469.709298
# 11     974.580338
# ...

# %%
df.loc[(df["continent"]=="Europe") & (df["year"]>2000)]
# Out:
#                      country  year  population continent  life_exp  \
# 22                   Albania  2002     3508512    Europe    75.651
# 23                   Albania  2007     3600523    Europe    76.423
# 82                   Austria  2002     8148312    Europe    78.980
# 83                   Austria  2007     8199783    Europe    79.829
# 118                  Belgium  2002    10311970    Europe    78.320
# 119                  Belgium  2007    10392226    Europe    79.441
# 154   Bosnia and Herzegovina  2002     4165416    Europe    74.090
# 155   Bosnia and Herzegovina  2007     4552198    Europe    74.852
# 190                 Bulgaria  2002     7661799    Europe    72.140
# 191                 Bulgaria  2007     7322858    Europe    73.005
# 382                  Croatia  2002     4481020    Europe    74.876
# 383                  Croatia  2007     4493312    Europe    75.748
# 406           Czech Republic  2002    10256295    Europe    75.510
# ...

# %%
df.loc[(df["continent"]=="Europe") & (df["year"]>2000)].sort_values(by=["year","life_exp"],ascending=[True,False])
# Out:
#                      country  year  population continent  life_exp  \
# 1486             Switzerland  2002     7361757    Europe    80.620
# 694                  Iceland  2002      288030    Europe    80.500
# 778                    Italy  2002    57926999    Europe    80.240
# 1474                  Sweden  2002     8954175    Europe    80.040
# 1426                   Spain  2002    40152517    Europe    79.780
# 538                   France  2002    59925035    Europe    79.590
# 1150                  Norway  2002     4535591    Europe    79.050
# 82                   Austria  2002     8148312    Europe    78.980
# 574                  Germany  2002    82350671    Europe    78.670
# 1090             Netherlands  2002    16122830    Europe    78.530
# 1606          United Kingdom  2002    59912431    Europe    78.471
# 526                  Finland  2002     5193039    Europe    78.370
# 118                  Belgium  2002    10311970    Europe    78.320
# ...

# %%
users= pd.DataFrame({"user_id":[1,2,3,4],"name":["Vaibhav","Aman","Satyam","Rutuja"]})
users
# Out:
#    user_id     name
# 0        1  Vaibhav
# 1        2     Aman
# 2        3   Satyam
# 3        4   Rutuja

# %%
messages = pd.DataFrame({"user_id":[1,1,2,3,4],"msg":["hmm","acha","thikhe","go to hell","nice"]})
messages
# Out:
#    user_id         msg
# 0        1         hmm
# 1        1        acha
# 2        2      thikhe
# 3        3  go to hell
# 4        4        nice

# %%
pd.concat([users,messages],axis=1)
# Out:
#    user_id     name  user_id         msg
# 0      1.0  Vaibhav        1         hmm
# 1      2.0     Aman        1        acha
# 2      3.0   Satyam        2      thikhe
# 3      4.0   Rutuja        3  go to hell
# 4      NaN      NaN        4        nice

# %%
users.merge(messages,on="user_id",how="left")
# Out:
#    user_id     name         msg
# 0        1  Vaibhav         hmm
# 1        1  Vaibhav        acha
# 2        2     Aman      thikhe
# 3        3   Satyam  go to hell
# 4        4   Rutuja        nice

# %%
users.merge(messages,on="user_id",how="inner")
# Out:
#    user_id     name         msg
# 0        1  Vaibhav         hmm
# 1        1  Vaibhav        acha
# 2        2     Aman      thikhe
# 3        3   Satyam  go to hell
# 4        4   Rutuja        nice

# %%
messages.rename(columns={"user_id":"id"},inplace=True)

# %%
users.merge(messages,left_on="user_id",right_on="id",how="inner")
# Out:
#    user_id     name  id         msg
# 0        1  Vaibhav   1         hmm
# 1        1  Vaibhav   1        acha
# 2        2     Aman   2      thikhe
# 3        3   Satyam   3  go to hell
# 4        4   Rutuja   4        nice

# %%
titanic = pd.read_csv("C:/Users/Rhythm Shah/Downloads/airlock-on-edge.woolf.university__url=https2F2Fpublic_assets2F0002F3782Ftitanic.csv%3F1678168053&resourceId=86851cfc-5717-4246-b400-25f5ef82a2ce&studentId=0b9.txt")

titanic
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       3  female  26.0      0      0   7.9250        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         0       3    male   NaN      0      0   8.4583        Q   Third
# 4         1       2  female  14.0      1      0  30.0708        C  Second
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         1       1  female  38.0      1      0  71.2833        C   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town  pclass_1    price  gender
# 0       False  Southampton         3   7.9250  female
# ...

# %%
titanic.T.drop_duplicates(keep="first")
# Out:
#                        0          1            2           3          4  \
# survived               1          1            1           0          1
# pclass                 3          1            3           3          2
# sex               female     female       female        male     female
# age                 26.0       38.0         26.0         NaN       14.0
# sibsp                  0          1            0           0          1
# parch                  0          0            0           0          0
# fare               7.925    71.2833        7.925      8.4583    30.0708
# embarked               S          C            S           Q          C
# class              Third      First        Third       Third     Second
# adult_male         False      False        False        True      False
# embark_town  Southampton  Cherbourg  Southampton  Queenstown  Cherbourg
#
#                       5            6          7            8          9
# ...

# %%
titanic.drop_duplicates(keep ="first")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       3  female  26.0      0      0   7.9250        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 3         0       3    male   NaN      0      0   8.4583        Q   Third
# 4         1       2  female  14.0      1      0  30.0708        C  Second
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
#
#    adult_male  embark_town  pclass_1    price  gender
# 0       False  Southampton         3   7.9250  female
# 1       False    Cherbourg         1  71.2833  female
# 3        True   Queenstown         3   8.4583    male
# 4       False    Cherbourg         2  30.0708  female
# 6        True  Southampton         1  51.8625    male
# 8       False  Southampton         3  11.1333  female

# %%
titanic.drop_duplicates(keep ="last")
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         1       1  female  38.0      1      0  71.2833        C   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town  pclass_1    price  gender
# 2       False  Southampton         3   7.9250  female
# 5        True   Queenstown         3   8.4583    male
# 6        True  Southampton         1  51.8625    male
# 7       False    Cherbourg         1  71.2833  female
# 8       False  Southampton         3  11.1333  female
# 9       False    Cherbourg         2  30.0708  female

# %%
df1 = pd.DataFrame({'name': ['Jack','Ryan','Chris','Sam'],
'rank': [1, 2, 3, 4]})
df2 = pd.DataFrame({'name': ['Ryan', 'Sam', 'Chris', 'Jack'],
'rank': [3, 1, 4, 2]})

print(pd.merge(df1,df2, on="name"))
# Out:
#     name  rank_x  rank_y
# 0   Jack       1       2
# 1   Ryan       2       3
# 2  Chris       3       4
# 3    Sam       4       1

# %%
df1 = pd.read_csv("C:/Users/Rhythm Shah/Downloads/airlock-on-edge.woolf.university__url=https2F2Fpublic_assets2F0002F7172Fsales_dataset.csv%3F1651728217&resourceId=e324d3d6-7050-4bc9-a8aa-fd106e1abe7f&student.txt")
df1[df1["Country"]=="United Kingdom"]["StockCode"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0           85048
# 1          79323P
# 2          79323W
# 3           22041
# 4           21232
#             ...
# 1067350     22466
# 1067351     22061
# 1067352     23275
# 1067353     21217
# 1067354     20685
# Name: StockCode, Length: 981330, dtype: object>

# %%
df10 = pd.DataFrame({'cust_id':[101,102,103,104],'name':['rick','morty','pickle','jerry']})
df10
# Out:
#    cust_id    name
# 0      101    rick
# 1      102   morty
# 2      103  pickle
# 3      104   jerry

# %%
df10.isin([101, 102, 120])
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
df10.isin({'cust_id': [101, 102]})
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
df10.isin(df10.cust_id)
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2     True  False
# 3     True  False

# %%
df10.name.isin('rick')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df10.name.isin('rick')
#
# File c:\Users\Rhythm Shah\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:5563, in Series.isin(self, values)
#    5490 def isin(self, values) -> Series:
#    5491     """
#    5492     Whether elements in Series are contained in `values`.
#    5493
#    (...)
#    5561     dtype: bool
#    5562     """
# -> 5563     result = algorithms.isin(self._values, values)
#    5564     return self._constructor(result, index=self.index).__finalize__(
#    5565         self, method="isin"
#    5566     )
#
# File c:\Users\Rhythm Shah\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\algorithms.py:459, in isin(comps, values)
#     454     raise TypeError(
#     455         "only list-like objects are allowed to be passed "
# ...

# %%
df6 = pd.read_csv("C:/Users/Rhythm Shah/Downloads/airlock-on-edge.woolf.university__url=https2F2Fpublic_assets2F0002F7152Fsales_dataset.csv%3F1651726697&resourceId=725ae619-436a-4ee0-9c8b-69b4341f960e&student.txt")
df6
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df7 = df6.groupby("StockCode")
df7.head()
# Out:
#          Invoice StockCode                          Description  Quantity  \
# 0         489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1         489434    79323P                   PINK CHERRY LIGHTS        12
# 2         489434    79323W                  WHITE CHERRY LIGHTS        12
# 3         489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4         489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...          ...       ...                                  ...       ...
# 1065882   581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 1065883  C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
# 1065971   581492     23621   SET 10 CARDS DAVID'S MADONNA 17074         3
# 1065972   581492     23635  SET 10 CARDS CHRISTMAS HOLLY  17259         1
# 1065973   581492     23644    SET 10 CARDS CHRISTMAS TREE 16955         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
student_data = pd.DataFrame({
'school_code': ['s001','s002','s003','s001','s002','s004','s001','s003'],
'class': ['V', 'V', 'VI', 'VI', 'V', 'VI','IX','X'],
'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes','Jane','Martin'],
'age': [12, 12, 13, 13, 14, 12, 15, 20],
'height': [173, 192, 186, 167, 151, 159, 140, 160],
'weight': [35, 32, 33, 30, 31, 32, 40, 50]},
 index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6','S7','S8']) 

student_data
# Out:
#    school_code class            name  age  height  weight
# S1        s001     V  Alberto Franco   12     173      35
# S2        s002     V    Gino Mcneill   12     192      32
# S3        s003    VI     Ryan Parkes   13     186      33
# S4        s001    VI    Eesha Hinton   13     167      30
# S5        s002     V    Gino Mcneill   14     151      31
# S6        s004    VI    David Parkes   12     159      32
# S7        s001    IX            Jane   15     140      40
# S8        s003     X          Martin   20     160      50

# %%
grouped_data = student_data.groupby(['school_code', 'class'])      
print((grouped_data.size()))
# Out:
# school_code  class
# s001         IX       1
#              V        1
#              VI       1
# s002         V        2
# s003         VI       1
#              X        1
# s004         VI       1
# dtype: int64

# %%
n=1
rows_to_drop=student_data.groupby(['school_code']).tail(n).index
result1 = student_data.drop(rows_to_drop, axis=0)
print(result1)
# Out:
#    school_code class            name  age  height  weight
# S1        s001     V  Alberto Franco   12     173      35
# S2        s002     V    Gino Mcneill   12     192      32
# S3        s003    VI     Ryan Parkes   13     186      33
# S4        s001    VI    Eesha Hinton   13     167      30

# %%
df6 = pd.read_csv("C:/Users/Rhythm Shah/Downloads/airlock-on-edge.woolf.university__url=https2F2Fpublic_assets2F0002F7152Fsales_dataset.csv%3F1651726697&resourceId=725ae619-436a-4ee0-9c8b-69b4341f960e&student.txt")
df6
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df6["amt"]= df6["Quantity"]*df6["Price"]
df6
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country     amt
# ...

# %%
df6.sort_values("amt",ascending=False)
# Out:
#          Invoice StockCode                          Description  Quantity  \
# 1065882   581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 587080    541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 748132    556444     22502       PICNIC BASKET WICKER 60 PIECES        60
# 241827    512771         M                               Manual         1
# 432176    530715     84347  ROTATING SILVER ANGELS T-LIGHT HLDR      9360
# ...          ...       ...                                  ...       ...
# 748142   C556445         M                               Manual        -1
# 276274   A516228         B                      Adjust bad debt         1
# 179403   A506401         B                      Adjust bad debt         1
# 587085   C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 1065883  C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                  InvoiceDate     Price  Customer ID         Country        amt
# ...

# %%
df8 = df6.groupby('StockCode').sum()
df8.sort_values("Quantity",ascending=False)
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_27584\1266216097.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df8 = df6.groupby('StockCode').sum()
#            Quantity     Price  Customer ID        amt
# StockCode
# 84077        108545    298.18   14628933.0   24898.22
# 85123A        96066  17858.85   82772051.0  253720.02
# 85099B        95739   9779.10   52638365.0  181278.51
# 21212         95450   2336.45   40505241.0   52447.54
# 84879         80705   5483.78   42672530.0  131413.85
# ...             ...       ...          ...        ...
# 10120         -8350     18.58    1073333.0     139.80
# 23003         -8516     22.62     823491.0     226.20
# 23005        -14418    129.40    2907375.0    2147.13
# 22126        -16400      0.00          0.0       0.00
# ...

# %%
df6[df6["StockCode"]=="84077"]
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 1309     489561     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS        48
# 3548     489723     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS       288
# 4192     489802     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS         3
# 4531     489816     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS        48
# 4543     489819     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS        96
# ...         ...       ...                                ...       ...
# 1060258  581171     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS        48
# 1063701  581403     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS        48
# 1064307  581419     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS       288
# 1065828  581478     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS        48
# 1066009  581492     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS         1
#
#                  InvoiceDate  Price  Customer ID         Country    amt
# ...

# %%
df6
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country     amt
# ...

# %%
df1 = pd.DataFrame({"name": ['tobey', 'peter', 'chris', 'pratt'],'chem_score':[10, 9, 8, 7], 'phy_score':[7, 8, 9, 10], 'Hindi_score':[9, 9, 9, 9]})  
df2 = pd.DataFrame({"name": ['chris', 'pratt', 'andrew', 'tom'],'chem_score':[10, 10, 10, 9], 'maths_score':[6, 6, 7, 9], 'eng_score':[9, 10, 10, 9]})
df1
# Out:
#     name  chem_score  phy_score  Hindi_score
# 0  tobey          10          7            9
# 1  peter           9          8            9
# 2  chris           8          9            9
# 3  pratt           7         10            9

# %%
df2
# Out:
#      name  chem_score  maths_score  eng_score
# 0   chris          10            6          9
# 1   pratt          10            6         10
# 2  andrew          10            7         10
# 3     tom           9            9          9

# %%
df3 = df1.merge(df2,on="name")
df3
# Out:
#     name  chem_score_x  phy_score  Hindi_score  chem_score_y  maths_score  \
# 0  chris             8          9            9            10            6
# 1  pratt             7         10            9            10            6
#
#    eng_score
# 0          9
# 1         10

# %%
df3.mean(axis=1).tolist()
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_27584\1803906039.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df3.mean(axis=1).tolist()
# [8.5, 8.666666666666666]

# %%
(df1["chem_score"].mean()+df2["chem_score"].mean())/2
# Out:
# 9.125

# %%
df16 = pd.read_csv("C:/Users/Rhythm Shah/Downloads/airlock-on-edge.woolf.university__url=https2F2Fpublic_assets2F0002F7152Fsales_dataset.csv%3F1651726697&resourceId=725ae619-436a-4ee0-9c8b-69b4341f960e&student.txt")
df16
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df16[df16["Country"]=="United Kingdom"].nunique()
# Out:
# Invoice        49108
# StockCode       5303
# Description     5668
# Quantity         997
# InvoiceDate    43829
# Price           2651
# Customer ID     5410
# Country            1
# dtype: int64
